# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
gender = pd.read_csv('gender_submission.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train[['Name','Sex']]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
test['Name'].count()
# Out:
# 418

# %%
train['Name'].count()
# Out:
# 891

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
(train[["Survived","SibSp","Parch","Age","Fare"]].corr())
# Out:
#           Survived     SibSp     Parch       Age      Fare
# Survived  1.000000 -0.035322  0.081629 -0.077221  0.257307
# SibSp    -0.035322  1.000000  0.414838 -0.308247  0.159651
# Parch     0.081629  0.414838  1.000000 -0.189119  0.216225
# Age      -0.077221 -0.308247 -0.189119  1.000000  0.096067
# Fare      0.257307  0.159651  0.216225  0.096067  1.000000

# %%
(train, 'Parch','Survived')
# Out:
# (     PassengerId  Survived  Pclass  \
#  0              1         0       3
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  4              5         0       3
#  5              6         0       3
#  6              7         0       1
#  7              8         0       3
#  8              9         1       3
#  9             10         1       2
#  10            11         1       3
#  11            12         1       1
#  12            13         0       3
#  13            14         0       3
#  14            15         0       3
#  15            16         1       2
#  16            17         0       3
#  17            18         1       2
#  18            19         0       3
#  19            20         1       3
#  20            21         0       2
#  21            22         1       2
#  22            23         1       3
#  23            24         1       1
#  24            25         0       3
# ...

# %%
train['Women'] = np.where(train.Sex=='female',1,0)
train['Women']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     1
# 15     1
# 16     0
# 17     0
# 18     1
# 19     1
# 20     0
# 21     0
# 22     1
# 23     0
# 24     1
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    1
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    0
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    1
# 883    0
# 884    0
# 885    1
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Women, Length: 891, dtype: int32

# %%
np.where(train.Age>40,'Y','N')
# Out:
# array(['N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'Y', 'N',
#        'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'Y', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'Y', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'Y',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'Y',
#        'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y',
#        'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N',
# ...

# %%
np.where(train.Survived==1,train.Survived.count(),'No')
# Out:
# array(['No', '891', '891', '891', 'No', 'No', 'No', 'No', '891', '891',
#        '891', '891', 'No', 'No', 'No', '891', 'No', '891', 'No', '891',
#        'No', '891', '891', '891', 'No', '891', 'No', 'No', '891', 'No',
#        'No', '891', '891', 'No', 'No', 'No', '891', 'No', 'No', '891',
#        'No', 'No', 'No', '891', '891', 'No', 'No', '891', 'No', 'No',
#        'No', 'No', '891', '891', 'No', '891', '891', 'No', '891', 'No',
#        'No', '891', 'No', 'No', 'No', '891', '891', 'No', '891', 'No',
#        'No', 'No', 'No', 'No', '891', 'No', 'No', 'No', '891', '891',
#        'No', '891', '891', 'No', '891', '891', 'No', 'No', '891', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', '891', '891', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', '891', '891', 'No', '891', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', '891', 'No', '891', 'No', '891', '891', 'No', 'No', 'No',
# ...

# %%
Data= pd.DataFrame(train[['Survived', 'Name','Age']])
Data
# Out:
#      Survived                                               Name   Age
# 0           0                            Braund, Mr. Owen Harris  22.0
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2           1                             Heikkinen, Miss. Laina  26.0
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4           0                           Allen, Mr. William Henry  35.0
# 5           0                                   Moran, Mr. James   NaN
# 6           0                            McCarthy, Mr. Timothy J  54.0
# 7           0                     Palsson, Master. Gosta Leonard   2.0
# 8           1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9           1                Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10          1                    Sandstrom, Miss. Marguerite Rut   4.0
# 11          1                           Bonnell, Miss. Elizabeth  58.0
# ...

# %%
train[train.Name.str[0]=='Z']
# Out:
#      PassengerId  Survived  Pclass                   Name     Sex   Age  \
# 111          112         0       3   Zabour, Miss. Hileni  female  14.5
# 240          241         0       3  Zabour, Miss. Thamine  female   NaN
# 422          423         0       3     Zimmerman, Mr. Leo    male  29.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 111      1      0    2665  14.4542   NaN        C
# 240      1      0    2665  14.4542   NaN        C
# 422      0      0  315082   7.8750   NaN        S

# %%
a=train[train.Ticket.str[0]== 2655]
a
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
np.where(train.Ticket==2655)
# Out:
# (array([], dtype=int64),)

# %%
test[test.columns[2:4]]
# Out:
#                                                   Name     Sex
# 0                                     Kelly, Mr. James    male
# 1                     Wilkes, Mrs. James (Ellen Needs)  female
# 2                            Myles, Mr. Thomas Francis    male
# 3                                     Wirz, Mr. Albert    male
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5                           Svensson, Mr. Johan Cervin    male
# 6                                 Connolly, Miss. Kate  female
# 7                         Caldwell, Mr. Albert Francis    male
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9                              Davies, Mr. John Samuel    male
# 10                                    Ilieff, Mr. Ylio    male
# 11                          Jones, Mr. Charles Cresson    male
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female
# 13                                Howard, Mr. Benjamin    male
# ...

# %%
test.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
data= pd.read_csv('test.csv', index_col='Name')
data.loc[['Kelly, Mr. James','Myles, Mr. Thomas Francis', 'Wirz, Mr. Albert']]['Ticket']
# Out:
# Name
# Kelly, Mr. James             330911
# Myles, Mr. Thomas Francis    240276
# Wirz, Mr. Albert             315154
# Name: Ticket, dtype: object

# %%
find = pd.read_csv('test.csv', index_col='PassengerId')
find.loc[[895,899,999,953,678]]['Ticket']
# Out:
# C:\Users\Khizra Ali\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# PassengerId
# 895    315154
# 899    248738
# 999    383162
# 953    237216
# 678       NaN
# Name: Ticket, dtype: object

# %%
test.sort_values(by= ['Name','Ticket'])
# Out:
#      PassengerId  Pclass                                               Name  \
# 392         1284       3                      Abbott, Master. Eugene Joseph
# 345         1237       3                        Abelseth, Miss. Karen Marie
# 57           949       3                      Abelseth, Mr. Olaus Jorgensen
# 251         1143       3           Abrahamsson, Mr. Abraham August Johannes
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 307         1199       3                          Aks, Master. Philip Frank
# 78           970       2                     Aldworth, Mr. Charles Augustus
# 306         1198       1               Allison, Mr. Hudson Joshua Creighton
# 210         1102       3                        Andersen, Mr. Albert Karvin
# 214         1106       3             Andersson, Miss. Ida Augusta Margareta
# 320         1212       3                        Andersson, Mr. Johan Samuel
# ...

# %%
train.tail(6)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 885  female  39.0      0      5      382652  29.125   NaN        Q
# 886    male  27.0      0      0      211536  13.000   NaN        S
# 887  female  19.0      0      0      112053  30.000   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.450   NaN        S
# 889    male  26.0      0      0      111369  30.000  C148        C
# ...

# %%
train['Death Count']=['Dead' if survived==0 else 'Alive' for survived in train['Survived']]
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Death Count
# 0      0         A/5 21171   7.2500   NaN        S        Dead
# 1      0          PC 17599  71.2833   C85        C       Alive
# 2      0  STON/O2. 3101282   7.9250   NaN        S       Alive
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Death Count    891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Death Count
# 0      0         A/5 21171   7.2500   NaN        Dead
# 1      0          PC 17599  71.2833   C85       Alive
# 2      0  STON/O2. 3101282   7.9250   NaN       Alive

# %%
not_survived = train["Fare"][train["Survived"] == 0]
#not_survived

# %%
not_survived.count()
# Out:
# 549

# %%
survived= train['Name'][train["Survived"] == 1]

# %%
survived.count()
# Out:
# 342

# %%
name= train['Name'][train["Ticket"] == 'PC 17599']
name
# Out:
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# Name: Name, dtype: object

# %%
Age = test[['Age','Sex','Ticket']][test['Name']=='Assam, Mr. Ali']
Age
# Out:
#       Age   Sex              Ticket
# 325  23.0  male  SOTON/O.Q. 3101309

# %%
Age_mean = train.Age.mean()
Age_mean
# Out:
# 29.69911764705882

# %%
gender.head(5)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
pd.read_csv('gender_submission.csv' ,names= ['a','b','c'])
# Out:
#                a         b   c
# 0    PassengerId  Survived NaN
# 1            892         0 NaN
# 2            893         1 NaN
# 3            894         0 NaN
# 4            895         0 NaN
# 5            896         1 NaN
# 6            897         0 NaN
# 7            898         1 NaN
# 8            899         0 NaN
# 9            900         1 NaN
# 10           901         0 NaN
# 11           902         0 NaN
# 12           903         0 NaN
# 13           904         1 NaN
# 14           905         0 NaN
# 15           906         1 NaN
# 16           907         1 NaN
# 17           908         0 NaN
# 18           909         0 NaN
# 19           910         1 NaN
# 20           911         1 NaN
# 21           912         0 NaN
# 22           913         0 NaN
# 23           914         1 NaN
# 24           915         0 NaN
# 25           916         1 NaN
# 26           917         0 NaN
# 27           918         1 NaN
# 28           919         0 NaN
# ...

# %%
pd.read_csv('gender_submission.csv' ,names= ['a','b','c'], index_col=1)
# Out:
#                     a   c
# b
# Survived  PassengerId NaN
# 0                 892 NaN
# 1                 893 NaN
# 0                 894 NaN
# 0                 895 NaN
# 1                 896 NaN
# 0                 897 NaN
# 1                 898 NaN
# 0                 899 NaN
# 1                 900 NaN
# 0                 901 NaN
# 0                 902 NaN
# 0                 903 NaN
# 1                 904 NaN
# 0                 905 NaN
# 1                 906 NaN
# 1                 907 NaN
# 0                 908 NaN
# 0                 909 NaN
# 1                 910 NaN
# 1                 911 NaN
# 0                 912 NaN
# 0                 913 NaN
# 1                 914 NaN
# 0                 915 NaN
# 1                 916 NaN
# 0                 917 NaN
# 1                 918 NaN
# 0                 919 NaN
# 0                 920 NaN
# ...               ...  ..
# 0                1280 NaN
# 0                1281 NaN
# 0                1282 NaN
# ...

# %%
pd.isnull(train)
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
train['Embarked'] = train['Embarked'].fillna('S')

# %%
train['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
# 5      Q
# 6      S
# 7      S
# 8      S
# 9      C
# 10     S
# 11     S
# 12     S
# 13     S
# 14     S
# 15     S
# 16     Q
# 17     S
# 18     S
# 19     C
# 20     S
# 21     S
# 22     Q
# 23     S
# 24     S
# 25     S
# 26     C
# 27     S
# 28     Q
# 29     S
#       ..
# 861    S
# 862    S
# 863    S
# 864    S
# 865    S
# 866    C
# 867    S
# 868    S
# 869    S
# 870    S
# 871    S
# 872    S
# 873    S
# 874    C
# 875    C
# 876    S
# 877    S
# 878    S
# 879    C
# 880    S
# 881    S
# 882    S
# 883    S
# 884    S
# 885    Q
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
train[['PassengerId','SibSp','Parch']][train['Name']=='Braund, Mr. Owen Harris']
# Out:
#    PassengerId  SibSp  Parch
# 0            1      1      0

# %%
train.shape
# Out:
# (891, 12)

# %%
train.drop(['Cabin'], axis=1, inplace = True)

# %%
train.shape
# Out:
# (891, 11)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
print('Average Age:',round(train['Age'].mean(),2))
# Out:
# Average Age: 29.7

# %%
train['Age'] = train['Age'].fillna(29.7)
#train['Age']

# %%
train['Age'][train['Name']=='Johnston, Miss. Catherine Helen "Carrie"']
# Out:
# 888    29.7
# Name: Age, dtype: float64

# %%
train[train.columns[0:3]]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# ...

# %%
sns.countplot(train['Survived'])
plt.title('Not Survived and Survived')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %%
first_class_count = (train['Pclass'] == 1).sum()
print('1st Class:', first_class_count)
second_class_count = (train['Pclass'] == 2).sum()
print('2nd Class:',second_class_count)
third_class_count = (train['Pclass'] == 3).sum()
print('3rd Class:',third_class_count)
# Out:
# 1st Class: 216
# 2nd Class: 184
# 3rd Class: 491

# %%
labels = ['First Class', 'Second Class', 'Third Class']
sizes = [first_class_count, second_class_count, third_class_count]
plt.pie(sizes, labels=labels, autopct= '%1.3f%%' ) #autopct show values on pie 1.2 means upto 2 decimal places
plt.axis('equal') #pie look like circle
plt.title('Class Distribution')
plt.show()

# %%
sns.countplot(train['Pclass'])
plt.title('Class Distribution')
plt.xlabel('Classes')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12,6)) #graph size 12 by 8
sns.countplot(x = train['Pclass'], hue = train['Survived'])
plt.title('Survived w.r.t Class')
plt.xlabel('Classes')
plt.ylabel('Count')
plt.show()

# %%
axs = sns.kdeplot(train.Pclass[train.Survived == 0], label = 'Died')
axs = sns.kdeplot(train.Pclass[train.Survived == 1], label = 'Alive')
plt.title('Survived vs Class')
plt.xlabel('Classes')
plt.ylabel('Normalized Count')
plt.show()

# %%
plt.figure(figsize=(18,9))
axs = sns.kdeplot(train.Age[train.Survived == 0], shade=True, label = 'Died')
axs = sns.kdeplot(train.Age[train.Survived == 1], shade=True, label = 'Survived')

plt.title('Survived vs Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#histogram
plt.figure(figsize=(18,9))
train.hist(column='Age', bins=80)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
train.Age.max()
# Out:
# 80.0

# %%
round(train.Age.mean(),2)
# Out:
# 29.7

# %%
train.hist(column='Fare', bins = 200)
plt.title('Fare Dist')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.show()

# %%
survived_above_500 = ((train['Fare']>500) & (train['Survived']==1)).sum()
print('People survived who paid more than $500 are',survived_above_500)
# Out:
# People survived who paid more than $500 are 3

# %%
train.loc[train['Fare']>500]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
#scatter graph
plt.figure(figsize=(12,8))
plt.scatter(train['Age'], train['Fare']) # plt(x,y)
plt.title('Age wrt Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
male_dead=((train['Sex']=='male') & (train['Survived']==0))
print('Out of 891 the men died in Titanic are ', male_dead.sum())
male_survived=((train['Sex']=='male') & (train['Survived']==1))
print('Out of 891 the men survived in Titanic are ', male_survived.sum())
female_dead=((train['Sex']=='female') & (train['Survived']==0))
print('Out of 891 the women died in Titanic are ', female_dead.sum())
female_survived=((train['Sex']=='female') & (train['Survived']==1))
print('Out of 891 the women survived in Titanic are ', female_survived.sum())
# Out:
# Out of 891 the men died in Titanic are  468
# Out of 891 the men survived in Titanic are  109
# Out of 891 the women died in Titanic are  81
# Out of 891 the women survived in Titanic are  233

# %%
#bar graph
plt.figure(figsize=(12,8))
m_train = (male_dead, male_survived)
f_train = (female_dead, female_survived)
p1 = plt.bar(np.arange(2), (m_train), width=0.4)
p2 = plt.bar(np.arange(2), (f_train), bottom=m_data, width=0.4)
plt.xticks(np.arange(2), ['Men','Women'])
plt.legend((p1[0], p2[0]), ('Died', 'Survived'))
plt.title('Men vs Women Survival')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-3ed7a51eeb30> in <module>
#       3 m_train = (male_dead, male_survived)
#       4 f_train = (female_dead, female_survived)
# ----> 5 p1 = plt.bar(np.arange(2), (m_train), width=0.4)
#       6 p2 = plt.bar(np.arange(2), (f_train), bottom=m_data, width=0.4)
#       7 plt.xticks(np.arange(2), ['Men','Women'])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2455     return gca().bar(
#    2456         x, height, width=width, bottom=bottom, align=align,
# -> 2457         **({"data": data} if data is not None else {}), **kwargs)
#    2458
#    2459
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
sns.countplot(x=train['Embarked'])
plt.title('Count')
plt.xlabel('On Board')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.countplot(x=train['Embarked'], hue=train['Survived'])
plt.title('Count')
plt.xlabel('On Board vs Survival')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#heat map show relationships between columns with 1 has highest and 0 has lowest relativity
#takes only int values so no sex and embarked column

plt.figure(figsize=(12,8))
graph = sns.heatmap(train.corr().abs(), annot=True)
plt.show()

# %%
train['Sex'] = train['Sex'].replace('male',1)
train['Sex'] = train['Sex'].replace('female',0)

# %%
train['Embarked'] = train['Embarked'].replace('C',1)
train['Embarked'] = train['Embarked'].replace('Q',2)
train['Embarked'] = train['Embarked'].replace('S',3)

# %%
#after converting str valeue sto int
plt.figure(figsize=(12,8))
graph = sns.heatmap(train.corr().abs(), annot=True)
plt.show()
